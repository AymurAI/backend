# %%
import logfire

logfire.configure(service_name="aymurai")
_ = logfire.instrument_openai()
# Out:
# Logfire project URL: ]8;id=180752;https://logfire-us.pydantic.dev/sofia-delpozo/aymurai\https://logfire-us.pydantic.dev/sofia-delpozo/aymurai]8;;\
