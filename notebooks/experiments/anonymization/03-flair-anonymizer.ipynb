# %%
import flair, random, torch

from flair.data import Corpus, Sentence
from flair.datasets import ColumnCorpus
from flair.embeddings import (
    FlairEmbeddings,
    TransformerWordEmbeddings,
    StackedEmbeddings,
)
from flair.models import SequenceTagger
from torch.optim.lr_scheduler import OneCycleLR
from flair.tokenization import SpaceTokenizer
from flair.trainers import ModelTrainer
from flair.visual.training_curves import Plotter


flair.device = torch.device("cpu")
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# ## Prepare dataset

# %%
# define columns
columns = {0: "text", 1: "ner"}

# this is the folder in which train, test and dev files reside
data_folder = "/resources/data/anonymization"

# 1. init a corpus using column format, data folder and the names of the train, dev and test files
corpus = ColumnCorpus(
    data_folder,
    columns,
    train_file="train.txt",
    test_file="test.txt",
    dev_file="dev.txt",
)
# Out:
# 2025-08-21 14:24:22,289 Reading data from /resources/data/anonymization
# 2025-08-21 14:24:22,291 Train: /resources/data/anonymization/train.txt
# 2025-08-21 14:24:22,292 Dev: /resources/data/anonymization/dev.txt
# 2025-08-21 14:24:22,293 Test: /resources/data/anonymization/test.txt

# %%
for i in range(10):
    print(corpus.train[i])
# Out:
# Sentence[11]: "2021 - Año del Bicentenario de la Universidad de Buenos Aires"
# Sentence[14]: "JUZGADO DE 1RA INSTANCIA EN LO PENAL CONTRAVENCIONAL Y DE FALTAS N°10 SECRETARIA N°19"
# Sentence[9]: "PADULA, DIEGO SEBASTIAN SOBRE 183 - DAÑOS Y OTROS" → ["PADULA, DIEGO SEBASTIAN"/PER]
# Sentence[3]: "Número: IPP 135033/2021-0" → ["IPP 135033/2021-0"/NUM_EXPEDIENTE]
# Sentence[3]: "CUIJ: IPP J-01-00135033-8/2021-0" → ["IPP J-01-00135033-8/2021-0"/CUIJ]
# Sentence[3]: "Actuación Nro: 1446853/2021" → ["1446853/2021"/NUM_ACTUACION]
# Sentence[5]: "AUDIENCIA EN LOS TÉRMINOS DEL"
# Sentence[4]: "ART. 28 LEY 26.485"
# Sentence[1]: "VIDEOCONFERENCIA"
# Sentence[6]: "Fecha: 30 de julio de 2021"

# %%
for i in range(10):
    print(corpus.dev[i])
# Out:
# Sentence[9]: "MENDOZA ZAPATA, LUIS IVAN SOBRE 89 - LESIONES LEVES" → ["MENDOZA ZAPATA, LUIS IVAN"/PER]
# Sentence[3]: "Número: IPP 90952/2021-0" → ["IPP 90952/2021-0"/NUM_EXPEDIENTE]
# Sentence[3]: "CUIJ: IPP J-01-00090952-8/2021-0" → ["IPP J-01-00090952-8/2021-0"/CUIJ]
# Sentence[3]: "Actuación Nro: 2238574/2021" → ["2238574/2021"/NUM_ACTUACION]
# Sentence[6]: "Fecha: 13 de octubre de 2021"
# Sentence[5]: "Horario de inicio: 13:20 horas"
# Sentence[9]: "Defensoría: Bibiana Birriel, a cargo de la Defensoría 18."
# Sentence[1]: "https://jusbaires.webex.com/jusbaires/ldr.php?RCID=b6ac8fdf60a698640da7bfc6997cd839" → ["https://jusbaires.webex.com/jusbaires/ldr.php?RCID=b6ac8fdf60a698640da7bfc6997cd839"/LINK]
# Sentence[2]: "Contraseña: pW7a9daP" → ["pW7a9daP"/TEXTO_ANONIMIZAR]
# Sentence[41]: "Principal Rodríguez (número 3) y Comisario Du Santos (punto 4), que firman la declaración testimonial de la víctima, son superfluos. Desiste de esos dos testigos y sostiene el resto de la prueba. No se opone a la prueba de la defensa." → ["Principal Rodríguez"/PER, "Comisario Du Santos"/PER]

# %%
for i in range(10):
    print(corpus.test[i])
# Out:
# Sentence[24]: "SUAREZ, NELSON ARTURO SOBRE 2 BIS - INCUMPLIMIENTO DE LOS DEBERES DE ASISTENCIA FAMILIAR (DESTRUCCION DE BIENES O DISMINUCION DE VALOR PARA ELUDIR CUMPLIMIENTO)" → ["SUAREZ, NELSON ARTURO"/PER]
# Sentence[3]: "Número: IPP 130521/2021-0" → ["IPP 130521/2021-0"/CUIJ]
# Sentence[3]: "CUIJ: IPP J-01-00130521-9/2021-0" → ["IPP J-01-00130521-9/2021-0"/CUIJ]
# Sentence[3]: "Actuación Nro: 2339615/2021" → ["2339615/2021"/NUM_ACTUACION]
# Sentence[42]: "Fundamentó su pedido en poder avanzar con la investigación ya que se encuentran pendientes diligencias tendientes a notificar personalmente al Sr. Suárez respecto de la citación a la audiencia de intimación de los hechos en los términos del art. 172 del CPP." → ["Suárez"/PER]
# Sentence[24]: "También, aportó las constancias de lo actuado a partir de la denuncia realizada por la víctima de forma online el pasado 3 de junio." → ["3 de junio."/FECHA]
# Sentence[53]: "De allí surge que el 4 de junio personal de la OFAVYT contactó a la víctima y pudo precisar con mayor detalle la conflictiva en la que se halla inmersa junto con su hija de once años y su hijo de ocho años, quien hasta la fecha no fue reconocido por el acusado." → ["4 de junio"/FECHA]
# Sentence[48]: "Concretamente, explicó que luego de la separación con el Sr. Suárez (hace ocho años), éste se habría desvinculado se sus obligaciones parentales. Asimismo, frente a la advertencia de judicializar el incumplimiento, éste habría realizado un depósito en le mes de marzo y mayo de aproximadamente ocho mil pesos." → ["Suárez"/PER, "marzo y mayo de"/FECHA]
# Sentence[31]: "Por último, en dicha oportunidad refirió que desconocía su domicilio personal y laboral pero sí contaba con su número de teléfono celular y su correo electrónico como únicos datos de contacto."
# Sentence[88]: "El 14 de junio de 2021, la Fiscalía determinó que el presente caso tendría por objeto investigar si Nelson Arturo Suarez, en calidad de progenitor de su hija menor de edad Luisana Etelvina Suarez nacida el 3 de agosto del año 2009, domiciliada con su madre Gisela Romero en la calle Bruselas 785 del barrio de Versalles de la Provincia de Buenos Aires, omitió prestar los medios indispensables para su subsistencia, consistentes en aportes en concepto de vivienda, alimentación, salud, educación y recreación, en período aún no establecido." → ["14 de junio de 2021,"/FECHA, "Nelson Arturo Suarez,"/PER, "Luisana Etelvina Suarez"/PER, "3 de agosto del año 2009,"/FECHA, "Gisela Romero"/PER, "Bruselas 785"/DIRECCION, "Versalles de la Provincia de Buenos Aires,"/LOC]

# %%
# 2. what label do we want to predict?
label_type = "ner"

# %%
# 3. make the label dictionary from the corpus
vocab_dictionary = corpus.make_vocab_dictionary()
print(vocab_dictionary)
# Out:
# Dictionary with 39881 tags: <unk>, de, la, que, el, en, a, y, del, por, se, las, con, los, su, al, no, un, lo, para, una, le, es, como, En, caso, esta, art., este, acusado, o, Fiscalía, si, proceso, prueba, tiene, DE, lugar, cual, horas, respecto, Por, sus, domicilio, hechos, día, El, Juez:, suspensión, cuenta

# %%
# 4. make the vocab dictionary from the corpus
label_dictionary = corpus.make_label_dictionary(label_type=label_type, add_unk=True)
# Out:
# 2025-08-21 14:25:16,236 Computing label dictionary. Progress:
# 2it [00:00, 1849.34it/s]
# 16752it [00:00, 110773.00it/s]
# 2025-08-21 14:25:16,403 Dictionary created for label 'ner' with 27 values: PER (seen 5609 times), FECHA (seen 2629 times), DIRECCION (seen 946 times), DNI (seen 855 times), TEXTO_ANONIMIZAR (seen 653 times), NUM_EXPEDIENTE (seen 616 times), LOC (seen 611 times), NUM_ACTUACION (seen 489 times), CUIJ (seen 369 times), TELEFONO (seen 307 times), LINK (seen 193 times), EDAD (seen 190 times), CORREO_ELECTRONICO (seen 157 times), NACIONALIDAD (seen 115 times), BANCO (seen 112 times), MARCA_AUTOMOVIL (seen 102 times), PATENTE_DOMINIO (seen 84 times), CUIT_CUIL (seen 73 times), ESTUDIOS (seen 66 times), CBU (seen 58 times)

# %%
print(corpus.obtain_statistics())
# Out:
# {
#     "TRAIN": {
#         "dataset": "TRAIN",
#         "total_number_of_documents": 16752,
#         "number_of_documents_per_class": {
#             "PER": 5609,
#             "NUM_EXPEDIENTE": 616,
#             "CUIJ": 369,
#             "NUM_ACTUACION": 489,
#             "DNI": 855,
#             "LINK": 193,
#             "TELEFONO": 307,
#             "FECHA": 2629,
#             "DIRECCION": 946,
#             "TEXTO_ANONIMIZAR": 653,
#             "LOC": 611,
#             "NACIONALIDAD": 115,
#             "EDAD": 190,
#             "CORREO_ELECTRONICO": 157,
#             "NOMBRE_ARCHIVO": 14,
#             "BANCO": 112,
#             "NUM_MATRICULA": 21,
#             "ESTUDIOS": 66,
#             "IP": 17,
#             "USUARIX": 21,
#             "LUGAR_HECHO": 49,
#             "CUIT_CUIL": 73,
#             "CBU": 58,
#             "MARCA_AUTOMOVIL": 102,
#             "PATENTE_DOMINIO": 84,
#             "NUM_CAJA_AHORRO": 5
#         },
#         "number_of_tokens_per_tag": {},
#         "number_of_tokens": {
#             "total": 629001,
#             "min": 1,
#             "max": 1691,
#             "avg": 37.54781518624642
#         }
#     },
#     "TEST": {
#         "dataset": "TEST",
#         "total_number_of_documents": 1498,
#         "number_of_documents_per_class": {
#             "PER": 459,
#             "CUIJ": 50,
#             "NUM_ACTUACION": 51,
#             "FECHA": 191,
#             "DIRECCION": 98,
#             "LOC": 32,
#             "NUM_EXPEDIENTE": 27,
#             "PATENTE_DOMINIO": 10,
#             "TEXTO_ANONIMIZAR": 58,
#             "DNI": 91,
#             "LINK": 18,
#             "NACIONALIDAD": 16,
#             "ESTUDIOS": 7,
#             "TELEFONO": 27,
#             "CORREO_ELECTRONICO": 10,
#             "CBU": 6,
#             "CUIT_CUIL": 6,
#             "BANCO": 6,
#             "LUGAR_HECHO": 6
#         },
#         "number_of_tokens_per_tag": {},
#         "number_of_tokens": {
#             "total": 56362,
#             "min": 1,
#             "max": 430,
#             "avg": 37.62483311081442
#         }
#     },
#     "DEV": {
#         "dataset": "DEV",
#         "total_number_of_documents": 1748,
#         "number_of_documents_per_class": {
#             "PER": 583,
#             "NUM_EXPEDIENTE": 56,
#             "CUIJ": 29,
#             "NUM_ACTUACION": 49,
#             "LINK": 22,
#             "TEXTO_ANONIMIZAR": 70,
#             "FECHA": 255,
#             "DNI": 106,
#             "NUM_MATRICULA": 1,
#             "LOC": 89,
#             "DIRECCION": 120,
#             "LUGAR_HECHO": 8,
#             "MARCA_AUTOMOVIL": 18,
#             "PATENTE_DOMINIO": 18,
#             "NACIONALIDAD": 20,
#             "EDAD": 14,
#             "ESTUDIOS": 8,
#             "CORREO_ELECTRONICO": 12,
#             "TELEFONO": 26,
#             "BANCO": 15,
#             "CBU": 4,
#             "USUARIX": 4,
#             "CUIT_CUIL": 4
#         },
#         "number_of_tokens_per_tag": {},
#         "number_of_tokens": {
#             "total": 62497,
#             "min": 1,
#             "max": 356,
#             "avg": 35.753432494279174
#         }
#     }
# }

# %%
import pandas as pd
from ast import literal_eval

stats = literal_eval(corpus.obtain_statistics())

# %%
pd.Series(stats["TRAIN"]["number_of_documents_per_class"]).sort_values(ascending=False).plot(
    kind="bar", title="Train set - number of documents per label"
)
# Out:
# <Axes: title={'center': 'Train set - number of documents per label'}>

# %%
len(stats["TRAIN"]["number_of_documents_per_class"].keys())
# Out:
# 26

# %%
pd.Series(stats["DEV"]["number_of_documents_per_class"]).sort_values(ascending=False).plot(
    kind="bar", title="Dev set - number of documents per label"
)
# Out:
# <Axes: title={'center': 'Dev set - number of documents per label'}>

# %%
len(stats["DEV"]["number_of_documents_per_class"].keys())
# Out:
# 23

# %%
set(stats["TRAIN"]["number_of_documents_per_class"].keys()).symmetric_difference(
    set(stats["DEV"]["number_of_documents_per_class"].keys())
)
# Out:
# {'IP', 'NOMBRE_ARCHIVO', 'NUM_CAJA_AHORRO'}

# %%
pd.Series(stats["TEST"]["number_of_documents_per_class"]).sort_values(ascending=False).plot(
    kind="bar", title="Test set - number of documents per label"
)
# Out:
# <Axes: title={'center': 'Test set - number of documents per label'}>

# %%
len(stats["TEST"]["number_of_documents_per_class"].keys())
# Out:
# 19

# %%
set(stats["TRAIN"]["number_of_documents_per_class"].keys()).symmetric_difference(
    set(stats["TEST"]["number_of_documents_per_class"].keys())
)
# Out:
# {'EDAD',
#  'IP',
#  'MARCA_AUTOMOVIL',
#  'NOMBRE_ARCHIVO',
#  'NUM_CAJA_AHORRO',
#  'NUM_MATRICULA',
#  'USUARIX'}

# %% [markdown]
# ## Beto

# %% [markdown]
# #### No fine-tuning

# %%
# 5. initialize NON fine-tuneable transformer embeddings WITH document context
embeddings = TransformerWordEmbeddings(
    model="dccuchile/bert-base-spanish-wwm-cased",
    layers="-1",
    subtoken_pooling="first",
    fine_tune=False,
    use_context=True,
    allow_long_sentences=True,
)

# %%
# 6. initialize sequence tagger
tagger = SequenceTagger(
    hidden_size=256,
    embeddings=embeddings,
    tag_dictionary=label_dictionary,
    tag_type=label_type,
    use_crf=True,
    use_rnn=True,
    reproject_embeddings=True,
)

# %%
# 7. initialize trainer
trainer = ModelTrainer(
    tagger,
    corpus,
)

# %%
# 8. run training for 50 epochs
path = "/resources/ner/flair/anonymizer"

trainer.train(
    path,
    learning_rate=0.1,
    mini_batch_size=8,
    max_epochs=50,
    # scheduler=OneCycleLR,
    embeddings_storage_mode="none",
    weight_decay=0.0,
    use_final_model_for_eval=False,
)

# %%
plotter = Plotter()
plotter.plot_training_curves(f"{path}/loss.tsv", ["TRAIN_LOSS", "DEV_LOSS"])

# %% [markdown]
# ## Evaluation

# %%
# load model
tagger = SequenceTagger.load("aymurai/anonymizer-beto-cased-flair")
# Out:
# pytorch_model.bin:   0%|          | 0.00/451M [00:00<?, ?B/s]
# 2025-08-21 14:24:19,193 SequenceTagger predicts: Dictionary with 103 tags: O, S-PER, B-PER, E-PER, I-PER, S-FECHA, B-FECHA, E-FECHA, I-FECHA, S-DIRECCION, B-DIRECCION, E-DIRECCION, I-DIRECCION, S-DNI, B-DNI, E-DNI, I-DNI, S-TEXTO_ANONIMIZAR, B-TEXTO_ANONIMIZAR, E-TEXTO_ANONIMIZAR, I-TEXTO_ANONIMIZAR, S-LOC, B-LOC, E-LOC, I-LOC, S-NUM_EXPEDIENTE, B-NUM_EXPEDIENTE, E-NUM_EXPEDIENTE, I-NUM_EXPEDIENTE, S-NUM_ACTUACION, B-NUM_ACTUACION, E-NUM_ACTUACION, I-NUM_ACTUACION, S-CUIJ, B-CUIJ, E-CUIJ, I-CUIJ, S-TELEFONO, B-TELEFONO, E-TELEFONO, I-TELEFONO, S-EDAD, B-EDAD, E-EDAD, I-EDAD, S-LINK, B-LINK, E-LINK, I-LINK, S-CORREO_ELECTRONICO

# %%
# rewrite `label_dictionary` attribute to handle unknown items
tagger.label_dictionary = label_dictionary

# %%
evaluation = tagger.evaluate(
    corpus.test,
    label_type, "/evaluation.txt",
)
# Out:
#  38%|███▊      | 18/47 [12:07<18:58, 39.26s/it]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(evaluation.main_score, evaluation.loss)

# %%
print(evaluation.detailed_results)

# %%
import re
import pandas as pd

pd.set_option("display.max_rows", 100)

path = "/resources/ner/flair/anonymizer"
df = pd.read_csv(f"{path}/evaluation.txt", sep="\s", header=None)
df.columns = ["token", "label", "pred"]
df.head()

# %%
df.info()

# %%
df["label"].value_counts(normalize=True)

# %%
# Exact match
df["match"] = df["label"] == df["pred"]
df["match"].value_counts(normalize=True)

# %%
df.loc[df["label"] != "O", "match"].value_counts(normalize=True)

# %%
df.loc[df["label"] == "O", "match"].value_counts(normalize=True)

# %%
df.loc[(df["label"] == "O") & (df["match"] != 1)]

# %%
normalize_class = lambda x: re.sub(r"B-|I-", "", x)

df["normalized_label"] = df["label"].map(normalize_class)
df["normalized_pred"] = df["pred"].map(normalize_class)

# %%
df.head()

# %%
# Normalized exact match
df["normalized_match"] = df["normalized_label"] == df["normalized_pred"]
df["normalized_match"].value_counts(normalize=True)

# %%
df.loc[df["normalized_label"] != "O", "normalized_match"].value_counts(normalize=True)

# %%
df.loc[df["normalized_label"] == "O", "normalized_match"].value_counts(normalize=True)

# %%
df["normalized_pred"].value_counts(normalize=True)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(df["label"], df["pred"]))

# %%
print(classification_report(df["normalized_label"], df["normalized_pred"]))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20, 20))

labels = df["normalized_label"].unique()

cm = confusion_matrix(
    df["normalized_label"],
    df["normalized_pred"],
    labels=labels,
    normalize="true",
)

sns.heatmap(
    cm,
    vmin=0.0,
    vmax=1.0,
    cmap="Blues",
    annot=True,
    fmt=".2f",
    cbar=False,
    xticklabels=labels,
    yticklabels=labels,
)

plt.title("Confusion Matrix", fontdict={"fontsize": 20})

# %% [markdown]
# ## Inference

# %%
for sentence in corpus.test:
    tagger.predict(sentence)
    print(sentence)
    print()
    # print the entities with below command
    for entity in sentence.get_spans("ner"):
        print(entity)
    print("=" * 5)
